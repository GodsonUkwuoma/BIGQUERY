# %%
L = ['s','b','Anupma',45]

# %%
L[2][0:3]
# Out:
# 'Anu'

# %%
#append - adds an element at the last of the list
L.append(5)
#insert - adds an element at any index, you mention index and element you want to add
L.insert(0,'sumit')

# %%
# comparision  operator
'''
4 > 5   False
3 < 3   False
3 >= 3  True
4 <= 5  True
4 == 6  False
4 != 7  True


'''

# %%
# True and False are keywords in python
# reserved words for special puposes

True False and or not

# %%
# logical gates - and or not

# %%
4 > 5
# Out:
# False

# %%
4 == 4 and 3 > 5
# Out:
# False

# %%
if 1 > 2:
  print('hi')
  print('bye')
print('hello')
# Out:
# hello

# %%
a = 6
b =1
c = 20
if a > b:
    print('he')
if b > c:
    print('ssss')
if c>a:
    print('yes')
if a == 1:
    print('she')
# Out:
# he
# yes

# %%
if 50 > 1000:
  print('discount')
else:
  print('no discount')
